# %% [markdown]
# <a href="https://colab.research.google.com/github/pragmalingu/experiments/blob/master/Data/NPLCorpus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup an Elasticsearch Instance in Google Colab

# %% [markdown]
# Everthing to connect to Elasticsearch, for detailed explaination see [this Notebook.](https://)
# Download:

# %%
import os
from subprocess import Popen, PIPE, STDOUT
# download elasticsearch
# !wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.9.1-linux-x86_64.tar.gz -q
# !tar -xzf elasticsearch-7.9.1-linux-x86_64.tar.gz
# !chown -R daemon:daemon elasticsearch-7.9.1

# %% [markdown]
# Start a local server:

# %%
# start server
es_server = Popen(['elasticsearch-7.9.1/bin/elasticsearch'], 
                  stdout=PIPE, stderr=STDOUT,
                  preexec_fn=lambda: os.setuid(1)  # as daemon
                 )
# client-side
# !pip install elasticsearch -q
from elasticsearch import Elasticsearch
from datetime import datetime
es = Elasticsearch()
es.ping()  # got True

# %% [markdown]
# # Parsing NPL Corpus

# %% [markdown]
# You can get the corpus from [this link](http://ir.dcs.gla.ac.uk/resources/test_collections/npl/).  <br>
# For detailed information about the format of the files, see the PragmaLingu [ Benchmarks](https://pragmalingu.de/docs/benchmarks/overview)

# %% [markdown]
# ### Dowlnoad Data

# %% [markdown]
# Download and unzip data.

# %%
# !wget http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz
# !tar -xf npl.tar.gz

# %% [markdown]
# Set paths to the dowloaded data as variables:

# %%
PATH_TO_NPL_TXT = '/content/doc-text'
PATH_TO_NPL_QRY = '/content/query-text'
PATH_TO_NPL_REL = '/content/rlv-ass'

# %% [markdown]
# ### Imports

# %% [markdown]
# Make all the imports:

# %%
from collections import defaultdict
import re
import json
from io import StringIO
import numpy as np
import os

# %% [markdown]
# ### Process Data

# %% [markdown]
# Get the text entries from the text, query and relevance assessement files preprocessed as a list:

# %%
txt_entry_marker = re.compile('\n   /\n')
qry_entry_marker = re.compile('\n/\n')
rel_entry_marker = re.compile('\n   /\n')

def get_data(PATH_TO_FILES, marker):
  """
  Reads multiple files and spilts text into entries at the entry marker.
  The 'marker' contains the regex at which we want to split
  Pops last element since it's empty.
  """
  with open (PATH_TO_FILES,'r') as f:
    text = f.read()
    lines = re.split(marker,text)
    lines.pop()
  return lines

npl_txt_list = get_data(PATH_TO_NPL_TXT, txt_entry_marker)
npl_qry_list = get_data(PATH_TO_NPL_QRY, qry_entry_marker)
npl_rel_list = get_data(PATH_TO_NPL_REL, rel_entry_marker)

# %% [markdown]
# The entries in the text files only contain the ID and the text.

# %%
# process the documents

npl_txt_data = defaultdict(dict)

for entry in npl_txt_list:
  splitted = entry.split('\n')
  splitted = list(filter(None, splitted))
  ID = splitted[0]
  text = ' '.join(map(str, splitted[1:]))
  npl_txt_data[ID]['text'] = text

# %% [markdown]
# The query file is the same as the text file:

# %%
# process the queries

npl_qry_data = defaultdict(dict)

for entry in npl_qry_list:
  splitted = entry.split('\n')
  splitted = list(filter(None, splitted))
  ID = int(splitted[0])
  question = ' '.join(map(str, splitted[1:]))
  npl_qry_data[ID]['question'] = question

# %% [markdown]
# Relevance assesments are saved as numpy and parsed to dictionary:

# %%
# process relevance assesments

npl_rel = defaultdict(list)

for entry in npl_rel_list:
  splitted = entry.replace('\n','').split(' ')
  splitted = list(filter(None, splitted))
  ID = int(splitted[0])
  npl_rel[ID].extend(splitted[1:])

# %% [markdown]
# ### Create index for NPL corpus

# %% [markdown]
# Create an index for the NPL corpus. This is only possible if it isn't created yet.
#
# (For more information see the [Elasticsearch documentation](https://elasticsearch-py.readthedocs.io/en/master/api.html#elasticsearch.client.IndicesClient.create))

# %%
npl_index = "npl-corpus"

es.indices.create(npl_index)

create_response = es.cat.indices()
print(create_response)

# %% [markdown]
# Index all the documents that are processed to the created index in elasticsearch:
#
# (For more information see the [Elasticsearch documentation](https://elasticsearch-py.readthedocs.io/en/master/#example-usage))

# %%
for ID, doc_data in npl_txt_data.items():
  es.index(index=npl_index, id=ID, body=doc_data)

# %% [markdown]
# Verify if everthing went right by printing it:

# %%
create_response = es.cat.indices()
print(create_response)
# Out:
# ---------------------------------------------------------------------------
# TransportError                            Traceback (most recent call last)
# <ipython-input-13-77f0bb0f9776> in <module>()
# ----> 1 create_response = es.cat.indices()
#       2 print(create_response)
#
# /usr/local/lib/python3.6/dist-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#     137                 if p in kwargs:
#     138                     params[p] = kwargs.pop(p)
# --> 139             return func(*args, params=params, headers=headers, **kwargs)
#     140
#     141         return _wrapped
#
# /usr/local/lib/python3.6/dist-packages/elasticsearch/client/cat.py in indices(self, index, params, headers)
#     168         """
#     169         return self.transport.perform_request(
# --> 170             "GET", _make_path("_cat", "indices", index), params=params, headers=headers
#     171         )
#     172
#
# /usr/local/lib/python3.6/dist-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     350                     headers=headers,
#     351                     ignore=ignore,
# --> 352                     timeout=timeout,
#     353                 )
#     354
#
# /usr/local/lib/python3.6/dist-packages/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     254                 method, full_url, url, orig_body, duration, response.status, raw_data
#     255             )
# --> 256             self._raise_error(response.status, raw_data)
#     257
#     258         self.log_request_success(
#
# /usr/local/lib/python3.6/dist-packages/elasticsearch/connection/base.py in _raise_error(self, status_code, raw_data)
#     286
#     287         raise HTTP_EXCEPTIONS.get(status_code, TransportError)(
# --> 288             status_code, error_message, additional_info
#     289         )
#     290
#
# TransportError: TransportError(503, 'Open Distro Security not initialized.')

# %% [markdown]
# ### Use Corpus in Ranking API

# %% [markdown]
# Use the ranking evaluation API from elasticsearch to evaluate the corpus:
#
# (For more information see the [python documentation](https://elasticsearch-py.readthedocs.io/en/master/api.html?highlight=_rank_eval#elasticsearch.Elasticsearch.rank_eval) and the [Elasticsearch documentation](https://www.elastic.co/guide/en/elasticsearch/reference/current/search-rank-eval.html#search-rank-eval))

# %%
npl_index = "npl-corpus"

def create_query_body(query_dict, rel_dict, index_name):
  """
  The function creates a request for every query in query_dict and rates the relevant documents with rel_dict to 1.
  The index name has to be the same as from the documents your looking at.
  An evaluation body for the elasticsearch ranking API is returned.
  """
  eval_body = {
      "requests":'',
      "metric": {
          "recall": {
              "relevant_rating_threshold": 1,
              "k": 20
              }
      }
  }
  requests = [] 
  current_request = defaultdict(lambda: defaultdict())
  current_rel = {"_index": index_name, "_id": '', "rating": int}
  for query_ID, query_txt in query_dict.items():
    current_query = {"query": { "multi_match": { "query": '' , "fields" : ["title","text"]}}}
    current_query["query"]["multi_match"]["query"] = query_txt['question']
    current_request["id"] = 'Query_'+str(query_ID)
    current_request["request"] = current_query.copy()
    current_request["ratings"] = [{"_index": index_name, "_id": str(el), "rating": 1} for el in rel_dict[query_ID]]
    requests.append(current_request.copy())
  eval_body["requests"] = requests
  return eval_body

npl_create = create_query_body(npl_qry_data, npl_rel, npl_index)

npl_eval_body = json.dumps(npl_create)

# %% [markdown]
# Print results of Ranking API:

# %%
npl_res = es.rank_eval(npl_eval_body,npl_index)

print(json.dumps(npl_res, indent=4, sort_keys=True))
# Out:
# {
#     "details": {
#         "Query_1": {
#             "hits": [
#                 {
#                     "hit": {
#                         "_id": "4817",
#                         "_index": "npl-corpus",
#                         "_score": 16.205086,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8582",
#                         "_index": "npl-corpus",
#                         "_score": 16.07975,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8565",
#                         "_index": "npl-corpus",
#                         "_score": 14.960199,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "10652",
#                         "_index": "npl-corpus",
#                         "_score": 14.016545,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5502",
#                         "_index": "npl-corpus",
#                         "_score": 13.985805,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "10178",
#                         "_index": "npl-corpus",
#                         "_score": 13.860446,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8150",
#                         "_index": "npl-corpus",
#                         "_score": 13.570916,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "265",
#                         "_index": "npl-corpus",
#                         "_score": 13.483594,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8825",
#                         "_index": "npl-corpus",
#                         "_score": 12.84153,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "9591",
#                         "_index": "npl-corpus",
#                         "_score": 12.805502,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "4572",
#                         "_index": "npl-corpus",
#                         "_score": 12.700348,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "11212",
#                         "_index": "npl-corpus",
#                         "_score": 12.473767,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5145",
#                         "_index": "npl-corpus",
#                         "_score": 12.334066,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8172",
#                         "_index": "npl-corpus",
#                         "_score": 12.320855,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "5039",
#                         "_index": "npl-corpus",
#                         "_score": 11.978843,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "4463",
#                         "_index": "npl-corpus",
#                         "_score": 11.948393,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "9350",
#                         "_index": "npl-corpus",
#                         "_score": 11.913072,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "2800",
#                         "_index": "npl-corpus",
#                         "_score": 11.830738,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "1502",
#                         "_index": "npl-corpus",
#                         "_score": 11.777809,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "3693",
#                         "_index": "npl-corpus",
#                         "_score": 11.684383,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 }
#             ],
#             "metric_details": {
#                 "recall": {
#                     "relevant_docs": 19,
#                     "relevant_docs_retrieved": 4
#                 }
#             },
#             "metric_score": 0.21052631578947367,
#             "unrated_docs": [
#                 {
#                     "_id": "4817",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "8582",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "8565",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "10652",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "10178",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "265",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "8825",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "9591",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "4572",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "11212",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5145",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5039",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "4463",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "9350",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "2800",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "3693",
#                     "_index": "npl-corpus"
#                 }
#             ]
#         },
#         "Query_10": {
#             "hits": [
#                 {
#                     "hit": {
#                         "_id": "9530",
#                         "_index": "npl-corpus",
#                         "_score": 21.904356,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "10617",
#                         "_index": "npl-corpus",
#                         "_score": 17.381279,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "3384",
#                         "_index": "npl-corpus",
#                         "_score": 13.858995,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "4091",
#                         "_index": "npl-corpus",
#                         "_score": 13.387144,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "933",
#                         "_index": "npl-corpus",
#                         "_score": 13.235616,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "4329",
#                         "_index": "npl-corpus",
#                         "_score": 13.194855,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "3264",
#                         "_index": "npl-corpus",
#                         "_score": 12.520639,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "1621",
#                         "_index": "npl-corpus",
#                         "_score": 11.737833,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "1304",
#                         "_index": "npl-corpus",
#                         "_score": 11.700692,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "1934",
#                         "_index": "npl-corpus",
#                         "_score": 11.543371,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5855",
#                         "_index": "npl-corpus",
#                         "_score": 11.308473,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "8213",
#                         "_index": "npl-corpus",
#                         "_score": 11.248228,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "3938",
#                         "_index": "npl-corpus",
#                         "_score": 10.934785,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "631",
#                         "_index": "npl-corpus",
#                         "_score": 10.900694,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "10204",
#                         "_index": "npl-corpus",
#                         "_score": 10.703414,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5957",
#                         "_index": "npl-corpus",
#                         "_score": 10.635527,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "3053",
#                         "_index": "npl-corpus",
#                         "_score": 10.555866,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "2669",
#                         "_index": "npl-corpus",
#                         "_score": 10.386227,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "9770",
#                         "_index": "npl-corpus",
#                         "_score": 10.337412,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "11256",
#                         "_index": "npl-corpus",
#                         "_score": 10.299224,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 }
#             ],
#             "metric_details": {
#                 "recall": {
#                     "relevant_docs": 10,
#                     "relevant_docs_retrieved": 1
#                 }
#             },
#             "metric_score": 0.1,
#             "unrated_docs": [
#                 {
#                     "_id": "9530",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "10617",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "3384",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "4091",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "933",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "4329",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "3264",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "1621",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "1304",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "1934",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "8213",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "3938",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "631",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "10204",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5957",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "3053",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "2669",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "9770",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "11256",
#                     "_index": "npl-corpus"
#                 }
#             ]
#         },
#         "Query_11": {
#             "hits": [
#                 {
#                     "hit": {
#                         "_id": "7654",
#                         "_index": "npl-corpus",
#                         "_score": 14.067941,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "4139",
#                         "_index": "npl-corpus",
#                         "_score": 12.475649,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "7656",
#                         "_index": "npl-corpus",
#                         "_score": 11.307028,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "4925",
#                         "_index": "npl-corpus",
#                         "_score": 10.811774,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5024",
#                         "_index": "npl-corpus",
#                         "_score": 10.093227,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "74",
#                         "_index": "npl-corpus",
#                         "_score": 10.051911,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8219",
#                         "_index": "npl-corpus",
#                         "_score": 9.317502,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "4912",
#                         "_index": "npl-corpus",
#                         "_score": 9.118444,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "2945",
#                         "_index": "npl-corpus",
#                         "_score": 9.098243,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "7657",
#                         "_index": "npl-corpus",
#                         "_score": 9.089304,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "7602",
#                         "_index": "npl-corpus",
#                         "_score": 9.070798,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "1350",
#                         "_index": "npl-corpus",
#                         "_score": 9.039741,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "7793",
#                         "_index": "npl-corpus",
#                         "_score": 8.944529,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8106",
#                         "_index": "npl-corpus",
#                         "_score": 8.936272,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5453",
#                         "_index": "npl-corpus",
#                         "_score": 8.900358,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5670",
#                         "_index": "npl-corpus",
#                         "_score": 8.868812,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8141",
#                         "_index": "npl-corpus",
#                         "_score": 8.526587,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8207",
#                         "_index": "npl-corpus",
#                         "_score": 8.486434,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8343",
#                         "_index": "npl-corpus",
#                         "_score": 8.467925,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "9411",
#                         "_index": "npl-corpus",
#                         "_score": 8.457055,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 }
#             ],
#             "metric_details": {
#                 "recall": {
#                     "relevant_docs": 4,
#                     "relevant_docs_retrieved": 2
#                 }
#             },
#             "metric_score": 0.5,
#             "unrated_docs": [
#                 {
#                     "_id": "7654",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "4139",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "4925",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5024",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "74",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "4912",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "2945",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "7657",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "7602",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "1350",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "7793",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "8106",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5453",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5670",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "8141",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "8207",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "8343",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "9411",
#                     "_index": "npl-corpus"
#                 }
#             ]
#         },
#         "Query_12": {
#             "hits": [
#                 {
#                     "hit": {
#                         "_id": "4733",
#                         "_index": "npl-corpus",
#                         "_score": 19.494022,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "8095",
#                         "_index": "npl-corpus",
#                         "_score": 15.738607,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "162",
#                         "_index": "npl-corpus",
#                         "_score": 15.466051,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "659",
#                         "_index": "npl-corpus",
#                         "_score": 15.171762,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8132",
#                         "_index": "npl-corpus",
#                         "_score": 14.843671,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "6960",
#                         "_index": "npl-corpus",
#                         "_score": 14.824065,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8336",
#                         "_index": "npl-corpus",
#                         "_score": 14.694122,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "11318",
#                         "_index": "npl-corpus",
#                         "_score": 14.497164,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "1074",
#                         "_index": "npl-corpus",
#                         "_score": 14.440097,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "6043",
#                         "_index": "npl-corpus",
#                         "_score": 14.185421,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "2205",
#                         "_index": "npl-corpus",
#                         "_score": 14.179789,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5758",
#                         "_index": "npl-corpus",
#                         "_score": 14.155703,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "7684",
#                         "_index": "npl-corpus",
#                         "_score": 14.085096,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "3033",
#                         "_index": "npl-corpus",
#                         "_score": 14.064433,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "2203",
#                         "_index": "npl-corpus",
#                         "_score": 13.983518,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8467",
#                         "_index": "npl-corpus",
#                         "_score": 13.956811,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "657",
#                         "_index": "npl-corpus",
#                         "_score": 13.930618,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "7100",
#                         "_index": "npl-corpus",
#                         "_score": 13.6616535,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "426",
#                         "_index": "npl-corpus",
#                         "_score": 13.405199,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "3615",
#                         "_index": "npl-corpus",
#                         "_score": 13.2988205,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 }
#             ],
#             "metric_details": {
#                 "recall": {
#                     "relevant_docs": 39,
#                     "relevant_docs_retrieved": 5
#                 }
#             },
#             "metric_score": 0.1282051282051282,
#             "unrated_docs": [
#                 {
#                     "_id": "8095",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "162",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "659",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "6960",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "8336",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "11318",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "1074",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "6043",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "2205",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5758",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "7684",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "3033",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "2203",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "657",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "426",
#                     "_index": "npl-corpus"
#                 }
#             ]
#         },
#         "Query_13": {
#             "hits": [
#                 {
#                     "hit": {
#                         "_id": "5873",
#                         "_index": "npl-corpus",
#                         "_score": 24.24631,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "3398",
#                         "_index": "npl-corpus",
#                         "_score": 23.774855,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "3631",
#                         "_index": "npl-corpus",
#                         "_score": 20.892067,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "9552",
#                         "_index": "npl-corpus",
#                         "_score": 19.580915,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8346",
#                         "_index": "npl-corpus",
#                         "_score": 19.403685,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "2458",
#                         "_index": "npl-corpus",
#                         "_score": 18.92854,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "11053",
#                         "_index": "npl-corpus",
#                         "_score": 18.928474,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "11037",
#                         "_index": "npl-corpus",
#                         "_score": 18.260273,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "8464",
#                         "_index": "npl-corpus",
#                         "_score": 17.52394,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5989",
#                         "_index": "npl-corpus",
#                         "_score": 17.049706,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "6548",
#                         "_index": "npl-corpus",
#                         "_score": 16.901117,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "4454",
#                         "_index": "npl-corpus",
#                         "_score": 16.868296,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "7573",
#                         "_index": "npl-corpus",
#                         "_score": 16.78395,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8563",
#                         "_index": "npl-corpus",
#                         "_score": 16.771648,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "10192",
#                         "_index": "npl-corpus",
#                         "_score": 16.43702,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "5984",
#                         "_index": "npl-corpus",
#                         "_score": 16.226778,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5250",
#                         "_index": "npl-corpus",
#                         "_score": 16.113369,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8448",
#                         "_index": "npl-corpus",
#                         "_score": 15.85942,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "5276",
#                         "_index": "npl-corpus",
#                         "_score": 15.778511,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "5981",
#                         "_index": "npl-corpus",
#                         "_score": 15.620861,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 }
#             ],
#             "metric_details": {
#                 "recall": {
#                     "relevant_docs": 59,
#                     "relevant_docs_retrieved": 11
#                 }
#             },
#             "metric_score": 0.1864406779661017,
#             "unrated_docs": [
#                 {
#                     "_id": "3631",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "9552",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "8346",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "8464",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5989",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "7573",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5984",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5250",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5981",
#                     "_index": "npl-corpus"
#                 }
#             ]
#         },
#         "Query_14": {
#             "hits": [
#                 {
#                     "hit": {
#                         "_id": "11038",
#                         "_index": "npl-corpus",
#                         "_score": 19.58647,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8203",
#                         "_index": "npl-corpus",
#                         "_score": 19.04081,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5749",
#                         "_index": "npl-corpus",
#                         "_score": 18.648365,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "6260",
#                         "_index": "npl-corpus",
#                         "_score": 17.097921,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5536",
#                         "_index": "npl-corpus",
#                         "_score": 15.745797,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "8463",
#                         "_index": "npl-corpus",
#                         "_score": 15.597094,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "2311",
#                         "_index": "npl-corpus",
#                         "_score": 15.329589,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "6623",
#                         "_index": "npl-corpus",
#                         "_score": 14.469059,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5561",
#                         "_index": "npl-corpus",
#                         "_score": 14.422306,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "4832",
#                         "_index": "npl-corpus",
#                         "_score": 14.402297,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8124",
#                         "_index": "npl-corpus",
#                         "_score": 14.29458,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "5979",
#                         "_index": "npl-corpus",
#                         "_score": 13.763163,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5866",
#                         "_index": "npl-corpus",
#                         "_score": 13.719032,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "1065",
#                         "_index": "npl-corpus",
#                         "_score": 13.589204,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5650",
#                         "_index": "npl-corpus",
#                         "_score": 13.330148,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "3851",
#                         "_index": "npl-corpus",
#                         "_score": 13.259592,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5662",
#                         "_index": "npl-corpus",
#                         "_score": 12.880693,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "7083",
#                         "_index": "npl-corpus",
#                         "_score": 12.851612,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "10626",
#                         "_index": "npl-corpus",
#                         "_score": 12.826528,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8503",
#                         "_index": "npl-corpus",
#                         "_score": 12.681919,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 }
#             ],
#             "metric_details": {
#                 "recall": {
#                     "relevant_docs": 56,
#                     "relevant_docs_retrieved": 6
#                 }
#             },
#             "metric_score": 0.10714285714285714,
#             "unrated_docs": [
#                 {
#                     "_id": "11038",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "8203",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "6260",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "6623",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "4832",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5979",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5866",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "1065",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5650",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "3851",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5662",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "7083",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "10626",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "8503",
#                     "_index": "npl-corpus"
#                 }
#             ]
#         },
#         "Query_15": {
#             "hits": [
#                 {
# ...
#                         "_index": "npl-corpus",
#                         "_score": 24.101906,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "2632",
#                         "_index": "npl-corpus",
#                         "_score": 21.32617,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "6484",
#                         "_index": "npl-corpus",
#                         "_score": 20.06361,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "2225",
#                         "_index": "npl-corpus",
#                         "_score": 19.97876,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8874",
#                         "_index": "npl-corpus",
#                         "_score": 19.95859,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8873",
#                         "_index": "npl-corpus",
#                         "_score": 19.939796,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "10869",
#                         "_index": "npl-corpus",
#                         "_score": 19.623796,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "10668",
#                         "_index": "npl-corpus",
#                         "_score": 19.495562,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "1379",
#                         "_index": "npl-corpus",
#                         "_score": 18.71994,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "2833",
#                         "_index": "npl-corpus",
#                         "_score": 18.617065,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "2850",
#                         "_index": "npl-corpus",
#                         "_score": 18.556034,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5086",
#                         "_index": "npl-corpus",
#                         "_score": 18.417496,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "6640",
#                         "_index": "npl-corpus",
#                         "_score": 18.40345,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "313",
#                         "_index": "npl-corpus",
#                         "_score": 18.285263,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "84",
#                         "_index": "npl-corpus",
#                         "_score": 18.178846,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "2281",
#                         "_index": "npl-corpus",
#                         "_score": 18.02319,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "608",
#                         "_index": "npl-corpus",
#                         "_score": 17.75064,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "848",
#                         "_index": "npl-corpus",
#                         "_score": 17.46977,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 }
#             ],
#             "metric_details": {
#                 "recall": {
#                     "relevant_docs": 14,
#                     "relevant_docs_retrieved": 2
#                 }
#             },
#             "metric_score": 0.14285714285714285,
#             "unrated_docs": [
#                 {
#                     "_id": "1215",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "3571",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "2632",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "6484",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "2225",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "8874",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "8873",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "10668",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "1379",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "2833",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "2850",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5086",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "6640",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "313",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "84",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "2281",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "608",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "848",
#                     "_index": "npl-corpus"
#                 }
#             ]
#         },
#         "Query_93": {
#             "hits": [
#                 {
#                     "hit": {
#                         "_id": "2964",
#                         "_index": "npl-corpus",
#                         "_score": 21.767012,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "7802",
#                         "_index": "npl-corpus",
#                         "_score": 19.40057,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "533",
#                         "_index": "npl-corpus",
#                         "_score": 19.24306,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "1976",
#                         "_index": "npl-corpus",
#                         "_score": 18.862093,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "3256",
#                         "_index": "npl-corpus",
#                         "_score": 18.765947,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "2449",
#                         "_index": "npl-corpus",
#                         "_score": 17.026785,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "151",
#                         "_index": "npl-corpus",
#                         "_score": 16.81828,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "163",
#                         "_index": "npl-corpus",
#                         "_score": 16.366236,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "3150",
#                         "_index": "npl-corpus",
#                         "_score": 16.179474,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "2696",
#                         "_index": "npl-corpus",
#                         "_score": 15.5104885,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5645",
#                         "_index": "npl-corpus",
#                         "_score": 15.509941,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "789",
#                         "_index": "npl-corpus",
#                         "_score": 15.492293,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "10194",
#                         "_index": "npl-corpus",
#                         "_score": 14.8436575,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "1481",
#                         "_index": "npl-corpus",
#                         "_score": 14.674831,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "4733",
#                         "_index": "npl-corpus",
#                         "_score": 14.328489,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5259",
#                         "_index": "npl-corpus",
#                         "_score": 14.3224945,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "4442",
#                         "_index": "npl-corpus",
#                         "_score": 14.284611,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "8019",
#                         "_index": "npl-corpus",
#                         "_score": 14.213536,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "6609",
#                         "_index": "npl-corpus",
#                         "_score": 13.956031,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5045",
#                         "_index": "npl-corpus",
#                         "_score": 13.947388,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 }
#             ],
#             "metric_details": {
#                 "recall": {
#                     "relevant_docs": 46,
#                     "relevant_docs_retrieved": 2
#                 }
#             },
#             "metric_score": 0.043478260869565216,
#             "unrated_docs": [
#                 {
#                     "_id": "2964",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "7802",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "533",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "1976",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "3256",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "2449",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "151",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "163",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "3150",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "2696",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5645",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "789",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "10194",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "1481",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "4733",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "8019",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "6609",
#                     "_index": "npl-corpus"
#                 },
#                 {
#                     "_id": "5045",
#                     "_index": "npl-corpus"
#                 }
#             ]
#         }
#     },
#     "failures": {},
#     "metric_score": 0.23298862661267034
# }
