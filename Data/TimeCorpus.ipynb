# %% [markdown]
# <a href="https://colab.research.google.com/github/pragmalingu/experiments/blob/master/Data/TimeCorpus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup an Elasticsearch Instance in Google Colab

# %% [markdown]
# Everthing to connect to Elasticsearch, for detailed explaination see [this Notebook.](https://)
# Download:

# %%
import os
from subprocess import Popen, PIPE, STDOUT
# download elasticsearch
# !wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.9.1-linux-x86_64.tar.gz -q
# !tar -xzf elasticsearch-7.9.1-linux-x86_64.tar.gz
# !chown -R daemon:daemon elasticsearch-7.9.1

# %% [markdown]
# Start a local server:

# %%
# start server
es_server = Popen(['elasticsearch-7.9.1/bin/elasticsearch'], 
                  stdout=PIPE, stderr=STDOUT,
                  preexec_fn=lambda: os.setuid(1)  # as daemon
                 )
# client-side
# !pip install elasticsearch -q
from elasticsearch import Elasticsearch
from datetime import datetime
es = Elasticsearch()
es.ping()  # got True

# %% [markdown]
# # Parsing Time Corpus

# %% [markdown]
# You can get the corpus from [this link](http://ir.dcs.gla.ac.uk/resources/test_collections/time/).  <br>
# For detailed information about the format of the files, see the PragmaLingu [ Benchmarks](https://pragmalingu.de/docs/benchmarks/overview)

# %% [markdown]
# ### Dowlnoad Data

# %% [markdown]
# Download and unzip data.

# %%
# !wget http://ir.dcs.gla.ac.uk/resources/test_collections/time/time.tar.gz
# !tar -xf time.tar.gz

# %% [markdown]
# Set paths to the dowloaded data as variables:

# %%
PATH_TO_TIME_TXT = '/content/TIME.ALL'
PATH_TO_TIME_QRY = '/content/TIME.QUE'
PATH_TO_TIME_REL = '/content/TIME.REL'

# %% [markdown]
# ### Imports

# %% [markdown]
# Make all the imports:

# %%
from collections import defaultdict
import re
import json
from io import StringIO
import numpy as np
import os

# %% [markdown]
# ### Process Data

# %% [markdown]
# Get the text entries from the text and query file preprocessed as a list:

# %%
txt_entry_marker = re.compile('\*TEXT')
qry_entry_marker = re.compile('\*FIND    ')
def get_data(PATH_TO_FILES, marker):
  """
  Reads multiple files and spilts text into entries at the entry marker.
  The 'marker' contains the regex at which we want to split
  Pops last element since it's empty.
  """
  with open (PATH_TO_FILES,'r') as f:
    text = f.read()
    lines = re.split(marker,text)
    lines.pop(0)
  return lines

time_txt_list = get_data(PATH_TO_TIME_TXT, txt_entry_marker)
time_qry_list = get_data(PATH_TO_TIME_QRY, qry_entry_marker)

# %% [markdown]
# The entries in the text files contain information on the ID, the pubilcation date, the page and the text. Since we don't need the page we can split the text at the 'PAGE' marker.

# %%
page_split = re.compile('PAGE \d{3}')

time_txt_data = defaultdict(dict)
ID = 1
for entry in time_txt_list:
  splitted = re.split(page_split,entry)
  time_txt_data[ID]['text'] = splitted[1]
  ID += 1

# %% [markdown]
# The query file is easily parsed by splitting the elements at the newline marker and saving the second splitted element as ID while the following elements are the question:

# %%
time_qry_data = defaultdict(dict)
qry_split = re.compile('\n\n ')

for query in time_qry_list:
  entries = re.split(qry_split,query)
  time_qry_data[int(entries[0])]['question'] = entries[1]

# %% [markdown]
# Relevance assesments are saved as numpy and parsed to dictionary:

# %%
# process relevance assesments without rating
time_rel = defaultdict(list)

rel_marker = re.compile('            \n        ')
rel_split = re.compile('\n')

with open (PATH_TO_TIME_REL,'r') as f:
  for lines in f:
    line = lines.strip().replace('   ',' ').replace('  ',' ').split(' ')
    if len(line) > 1:
      time_rel[int(line[0])].extend(line[1:])

# %% [markdown]
# ### Create index for Time corpus

# %% [markdown]
# Create an index for the Time corpus. This is only possible if it isn't created yet.
#
# (For more information see the [Elasticsearch documentation](https://elasticsearch-py.readthedocs.io/en/master/api.html#elasticsearch.client.IndicesClient.create))

# %%
time_index = "time-corpus"

es.indices.create(time_index)

create_response = es.cat.indices()
print(create_response)

# %% [markdown]
# Index all the documents that are processed to the created index in elasticsearch:
#
# (For more information see the [Elasticsearch documentation](https://elasticsearch-py.readthedocs.io/en/master/#example-usage))

# %%
for ID, doc_data in time_txt_data.items():
  es.index(index=time_index, id=ID, body=doc_data)

# %% [markdown]
# Verify if everthing went right by printing it:

# %%
create_response = es.cat.indices()
print(create_response)
# Out:
# green  open porter-medline-corpus        m2NiUrTURhypZ2paB_BARw 1 0 1032   0     1mb     1mb
# green  open snowball-cranfield-corpus    LZOyuDGLT0-_8TH1nk5kgw 1 0 1400   0   1.5mb   1.5mb
# yellow open security-auditlog-2020.07.26 3KQWvUwlRHOYj3AeOYcfkg 1 1   31   0  75.6kb  75.6kb
# yellow open security-auditlog-2020.07.27 C3A4S_lhSC-y5NEvhhhAAg 1 1   20   0  36.9kb  36.9kb
# yellow open security-auditlog-2020.07.28 sLtcImDYTmafKHDoxhmg8g 1 1   22   0  72.3kb  72.3kb
# yellow open security-auditlog-2020.07.29 s_wFvB3PTeKWfVSZFdlgOw 1 1    9   0 123.3kb 123.3kb
# green  open snowball-medline-corpus      FqIexMbRRHKEBFapHtahZQ 1 0 1032   0     1mb     1mb
# green  open porter-index                 cF_QK9lTRBqtP5WjDcF4SA 1 0    1   0   4.5kb   4.5kb
# yellow open pragmalingu-cisi-corpus      CH3y6fjrR-6dlstL1FwRAQ 1 1    0   0    208b    208b
# green  open .opendistro_security         aOOHbiN_QwKao4FpRXXu7w 1 0    7   1  45.4kb  45.4kb
# green  open stemming-index               cphykMe_SEefw7_Hh-Ne6w 1 0    1   0   4.5kb   4.5kb
# yellow open security-auditlog-2020.07.24 RtdL1IsqTZu0wcDOgvGIgA 1 1   96   0 163.7kb 163.7kb
# yellow open cisi-corpus                  TYV93oPETnSojbHlxP_tUw 1 1 1460   0   2.6mb   2.6mb
# yellow open security-auditlog-2020.07.25 3B4O7qOhQx2xPKMp7cYIiw 1 1    8   0 110.9kb 110.9kb
# green  open .kibana_92668751_admin_1     VkJe6jjiSMSj77PJCniIZQ 1 0    1   0   3.8kb   3.8kb
# green  open stemmer-adi-corpus           9G-58drXRGmWLwMNgQ_tUA 1 0   82   0  80.9kb  80.9kb
# green  open stemmer-cranfield-corpus     FhZsfKWjTkSCh7bUZ2BwBQ 1 0 1400   0   1.5mb   1.5mb
# green  open .kibana_92668751_admin_2     jqG35SnPSluE8FaWoIYZmg 1 0    1   0   3.8kb   3.8kb
# yellow open pragmalingu-med-corpus       _cylNq05TXunMH3MJT7Fxg 1 1    0   0    208b    208b
# yellow open lisa-corpus                  lIJXnP3aS1qbgFRz-maA-Q 1 1 6000   0    10mb    10mb
# green  open .tasks                       Ak1djmqKRuqDf9Dw-TLwKQ 1 0    1   0   6.4kb   6.4kb
# yellow open cacm-corpus                  rhbI9n0MQ52xRBTArIYJ1A 1 1 3204   0   4.2mb   4.2mb
# yellow open security-auditlog-2020.08.02 hStsCYpbS-uhuSd3dyBFvg 1 1   15   0  95.5kb  95.5kb
# yellow open security-auditlog-2020.08.01 WO6XBXRnSPmu-Q3IIzXWdg 1 1   14   0  82.2kb  82.2kb
# yellow open security-auditlog-2020.08.04 1h2xSbNVQ9-kZx9TAzjOEA 1 1    8   0 116.9kb 116.9kb
# yellow open pragmalingu-cacm-corpus      PHpk31BeSKyeFWm4Eon56g 1 1    0   0    208b    208b
# yellow open security-auditlog-2020.08.03 Q2tbS9UUS3y5NIBxLJDHoA 1 1   26   0 123.1kb 123.1kb
# green  open kstem-medline-corpus         jdAUv57zTF2AQJrtqBpXdg 1 0 1032   0     1mb     1mb
# green  open kstem-adi-corpus             Up5BW3aQRR-T58RH76HKJQ 1 0   82   0  83.8kb  83.8kb
# green  open snowball-adi-corpus          RvNNOzKWQHS4em6qfaP7MA 1 0   82   0    88kb    88kb
# yellow open time-corpus                  Ge5qefcHRTuOn0USBWvZJA 1 1   97   0   1.3mb   1.3mb
# yellow open security-auditlog-2020.07.30 NnDU9kvORb2yutAOIeXr-g 1 1   10   0 141.6kb 141.6kb
# yellow open security-auditlog-2020.07.31 M3E0K2AzQVebCtny8uczyg 1 1   27   0   132kb   132kb
# green  open kstem-index                  SwH6GZrZT5apGcp3dBnlGw 1 0    1   0   4.5kb   4.5kb
# yellow open cranfield-corpus             -NFVyQ3nTYeJCa_Tn90Yuw 1 1 1400   0   1.7mb   1.7mb
# yellow open pragmalingu-test             f_mKvLYwT9uqrczeykbXxw 1 1    0   0    208b    208b
# green  open stemming-cacm-corpus         WW1gvxHeTk66Sj_Tp54Rpw 1 0 3204   0   4.1mb   4.1mb
# green  open stemming-cisi-corpus         CgNvnWf2RKuZQd2htUS0tA 1 0 1460   0   2.5mb   2.5mb
# yellow open pragmalingu-adi-corpus       dkEU6XPMSQm6hKrTsvtj2w 1 1    0   0    208b    208b
# green  open stemmer-medline-corpus       JhZC-N3PQFeC835uk4rnKg 1 0    0   0    208b    208b
# green  open stemmer-index                oew9DbhlSl2ofR1YG2o_CA 1 0    1   0   4.5kb   4.5kb
# yellow open stemmer-test-index           nvJ8HZbpSZKDf5P5SNFmfg 1 1    1   0   4.7kb   4.7kb
# yellow open stemming-medline-corpus      ld3Jn52eQrW7vQ4XL9o3jA 1 1 1032 224   1.3mb   1.3mb
# yellow open pragmalingu-cran-corpus      bDfOpaevTOmbENoJLNkcbw 1 1    0   0    208b    208b
# green  open kstem-cranfield-corpus       WDx2tYgST7eeiQ596SbYgw 1 0 1400   0   1.6mb   1.6mb
# green  open porter-adi-corpus            7kZ1okcCQjewGo5LXYZNsA 1 0   82   0  80.9kb  80.9kb
# yellow open stemming-cranfield-corpus    YMOO9bfFRx2QDjN3DIja6g 1 1 1400   0   1.6mb   1.6mb
# green  open porter-cranfield-corpus      -_Zu7W63RxSw0E6fQVLI8g 1 0 1400   0   1.5mb   1.5mb
# yellow open adi-corpus                   ilRyd4TWSW6zdBrSXoaPYQ 1 1   82   0  93.8kb  93.8kb
# green  open .kibana_1                    JQnZPkFUSmO1fr5WE0TSzw 1 0    0   0    208b    208b
# yellow open medline-corpus               NYo-Zrt5QRqyEGN2DdziTA 1 1 1032   0   1.1mb   1.1mb
# green  open snowball-index               qmApjGfPQhqFYqtCQIwPkQ 1 0    1   0   4.5kb   4.5kb
# green  open stemmer_index                pnka52e8RcWl197aO2MPjw 1 0    1   0  10.2kb  10.2kb
# green  open stemmer_index1               rrkXJIfIRgm-FXmC7Ftk7A 1 0    1   0   4.5kb   4.5kb

# %% [markdown]
# ### Use Corpus in Ranking API

# %% [markdown]
# Use the ranking evaluation API from elasticsearch to evaluate the corpus:
#
# (For more information see the [python documentation](https://elasticsearch-py.readthedocs.io/en/master/api.html?highlight=_rank_eval#elasticsearch.Elasticsearch.rank_eval) and the [Elasticsearch documentation](https://www.elastic.co/guide/en/elasticsearch/reference/current/search-rank-eval.html#search-rank-eval))

# %%
time_index = "time-corpus"

def create_query_body(query_dict, rel_dict, index_name):
  """
  The function creates a request for every query in query_dict and rates the relevant documents with rel_dict to 1.
  The index name has to be the same as from the documents your looking at.
  An evaluation body for the elasticsearch ranking API is returned.
  """
  eval_body = {
      "requests":'',
      "metric": {
          "recall": {
              "relevant_rating_threshold": 1,
              "k": 20
              }
      }
  }
  requests = [] 
  current_request = defaultdict(lambda: defaultdict())
  current_rel = {"_index": index_name, "_id": '', "rating": int}
  for query_ID, query_txt in query_dict.items():
    current_query = {"query": { "multi_match": { "query": '' , "fields" : ["title","text"]}}}
    current_query["query"]["multi_match"]["query"] = query_txt['question']
    current_request["id"] = 'Query_'+str(query_ID)
    current_request["request"] = current_query.copy()
    current_request["ratings"] = [{"_index": index_name, "_id": str(el), "rating": 1} for el in rel_dict[query_ID]]
    requests.append(current_request.copy())
  eval_body["requests"] = requests
  return eval_body

time_create = create_query_body(time_qry_data, time_rel, time_index)

time_eval_body = json.dumps(time_create)

# %% [markdown]
# Print results of Ranking API:

# %%
time_res = es.rank_eval(time_eval_body,time_index)

print(json.dumps(time_res, indent=4, sort_keys=True))
# Out:
# {
#     "details": {
#         "Query_1": {
#             "hits": [
#                 {
#                     "hit": {
#                         "_id": "304",
#                         "_index": "time-corpus",
#                         "_score": 21.359013,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "257",
#                         "_index": "time-corpus",
#                         "_score": 20.824394,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "288",
#                         "_index": "time-corpus",
#                         "_score": 20.80226,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "308",
#                         "_index": "time-corpus",
#                         "_score": 20.43621,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "268",
#                         "_index": "time-corpus",
#                         "_score": 20.211205,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "323",
#                         "_index": "time-corpus",
#                         "_score": 19.899931,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "326",
#                         "_index": "time-corpus",
#                         "_score": 19.378458,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "349",
#                         "_index": "time-corpus",
#                         "_score": 18.983633,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "334",
#                         "_index": "time-corpus",
#                         "_score": 17.073935,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "406",
#                         "_index": "time-corpus",
#                         "_score": 16.902637,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "370",
#                         "_index": "time-corpus",
#                         "_score": 15.68159,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "376",
#                         "_index": "time-corpus",
#                         "_score": 14.450365,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "359",
#                         "_index": "time-corpus",
#                         "_score": 13.246641,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "171",
#                         "_index": "time-corpus",
#                         "_score": 12.471672,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "211",
#                         "_index": "time-corpus",
#                         "_score": 12.267679,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "419",
#                         "_index": "time-corpus",
#                         "_score": 12.257165,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "395",
#                         "_index": "time-corpus",
#                         "_score": 11.7305565,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "382",
#                         "_index": "time-corpus",
#                         "_score": 11.5671425,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "350",
#                         "_index": "time-corpus",
#                         "_score": 10.935076,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "30",
#                         "_index": "time-corpus",
#                         "_score": 10.685816,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 }
#             ],
#             "metric_details": {
#                 "recall": {
#                     "relevant_docs": 7,
#                     "relevant_docs_retrieved": 7
#                 }
#             },
#             "metric_score": 1.0,
#             "unrated_docs": [
#                 {
#                     "_id": "257",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "349",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "406",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "370",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "376",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "359",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "171",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "211",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "419",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "395",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "382",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "350",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "30",
#                     "_index": "time-corpus"
#                 }
#             ]
#         },
#         "Query_10": {
#             "hits": [
#                 {
#                     "hit": {
#                         "_id": "61",
#                         "_index": "time-corpus",
#                         "_score": 29.455236,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "155",
#                         "_index": "time-corpus",
#                         "_score": 23.495718,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "269",
#                         "_index": "time-corpus",
#                         "_score": 20.094765,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "156",
#                         "_index": "time-corpus",
#                         "_score": 17.740402,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "358",
#                         "_index": "time-corpus",
#                         "_score": 13.225415,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "339",
#                         "_index": "time-corpus",
#                         "_score": 12.680477,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "303",
#                         "_index": "time-corpus",
#                         "_score": 12.556209,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "242",
#                         "_index": "time-corpus",
#                         "_score": 11.989621,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "258",
#                         "_index": "time-corpus",
#                         "_score": 9.424437,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "68",
#                         "_index": "time-corpus",
#                         "_score": 9.193444,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "309",
#                         "_index": "time-corpus",
#                         "_score": 8.391147,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "405",
#                         "_index": "time-corpus",
#                         "_score": 8.155436,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "49",
#                         "_index": "time-corpus",
#                         "_score": 7.511353,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "340",
#                         "_index": "time-corpus",
#                         "_score": 7.5108733,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "169",
#                         "_index": "time-corpus",
#                         "_score": 7.28904,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "384",
#                         "_index": "time-corpus",
#                         "_score": 7.079492,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "313",
#                         "_index": "time-corpus",
#                         "_score": 7.025804,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "139",
#                         "_index": "time-corpus",
#                         "_score": 7.001759,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "350",
#                         "_index": "time-corpus",
#                         "_score": 6.9279027,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "414",
#                         "_index": "time-corpus",
#                         "_score": 6.2819815,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 }
#             ],
#             "metric_details": {
#                 "recall": {
#                     "relevant_docs": 6,
#                     "relevant_docs_retrieved": 6
#                 }
#             },
#             "metric_score": 1.0,
#             "unrated_docs": [
#                 {
#                     "_id": "155",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "303",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "258",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "68",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "309",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "405",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "49",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "340",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "169",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "384",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "313",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "139",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "350",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "414",
#                     "_index": "time-corpus"
#                 }
#             ]
#         },
#         "Query_11": {
#             "hits": [
#                 {
#                     "hit": {
#                         "_id": "198",
#                         "_index": "time-corpus",
#                         "_score": 25.900137,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "195",
#                         "_index": "time-corpus",
#                         "_score": 19.655756,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "148",
#                         "_index": "time-corpus",
#                         "_score": 18.260134,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "135",
#                         "_index": "time-corpus",
#                         "_score": 16.801735,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "254",
#                         "_index": "time-corpus",
#                         "_score": 15.753835,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "25",
#                         "_index": "time-corpus",
#                         "_score": 13.362451,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "272",
#                         "_index": "time-corpus",
#                         "_score": 12.834233,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "364",
#                         "_index": "time-corpus",
#                         "_score": 11.775481,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "339",
#                         "_index": "time-corpus",
#                         "_score": 11.65841,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "269",
#                         "_index": "time-corpus",
#                         "_score": 11.545403,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "156",
#                         "_index": "time-corpus",
#                         "_score": 11.46013,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "121",
#                         "_index": "time-corpus",
#                         "_score": 10.965131,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "79",
#                         "_index": "time-corpus",
#                         "_score": 10.834387,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "382",
#                         "_index": "time-corpus",
#                         "_score": 10.771473,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "46",
#                         "_index": "time-corpus",
#                         "_score": 10.601228,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "238",
#                         "_index": "time-corpus",
#                         "_score": 10.384511,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "142",
#                         "_index": "time-corpus",
#                         "_score": 10.287577,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "371",
#                         "_index": "time-corpus",
#                         "_score": 10.193962,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "358",
#                         "_index": "time-corpus",
#                         "_score": 10.046632,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "72",
#                         "_index": "time-corpus",
#                         "_score": 10.031834,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 }
#             ],
#             "metric_details": {
#                 "recall": {
#                     "relevant_docs": 2,
#                     "relevant_docs_retrieved": 2
#                 }
#             },
#             "metric_score": 1.0,
#             "unrated_docs": [
#                 {
#                     "_id": "148",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "135",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "254",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "25",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "272",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "364",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "339",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "269",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "156",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "121",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "79",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "382",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "46",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "238",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "142",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "371",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "358",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "72",
#                     "_index": "time-corpus"
#                 }
#             ]
#         },
#         "Query_12": {
#             "hits": [
#                 {
#                     "hit": {
#                         "_id": "156",
#                         "_index": "time-corpus",
#                         "_score": 28.670261,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "61",
#                         "_index": "time-corpus",
#                         "_score": 27.783321,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "358",
#                         "_index": "time-corpus",
#                         "_score": 26.719696,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "242",
#                         "_index": "time-corpus",
#                         "_score": 25.927332,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "269",
#                         "_index": "time-corpus",
#                         "_score": 25.615963,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "155",
#                         "_index": "time-corpus",
#                         "_score": 24.67805,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "303",
#                         "_index": "time-corpus",
#                         "_score": 23.956133,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "339",
#                         "_index": "time-corpus",
#                         "_score": 17.46877,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "159",
#                         "_index": "time-corpus",
#                         "_score": 11.679738,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "139",
#                         "_index": "time-corpus",
#                         "_score": 11.256511,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "258",
#                         "_index": "time-corpus",
#                         "_score": 9.623857,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "309",
#                         "_index": "time-corpus",
#                         "_score": 9.377573,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "115",
#                         "_index": "time-corpus",
#                         "_score": 8.775199,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "238",
#                         "_index": "time-corpus",
#                         "_score": 8.516582,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "198",
#                         "_index": "time-corpus",
#                         "_score": 7.8020377,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "318",
#                         "_index": "time-corpus",
#                         "_score": 7.794022,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "251",
#                         "_index": "time-corpus",
#                         "_score": 7.6094427,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "323",
#                         "_index": "time-corpus",
#                         "_score": 7.1999803,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "90",
#                         "_index": "time-corpus",
#                         "_score": 7.193824,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "75",
#                         "_index": "time-corpus",
#                         "_score": 7.1925535,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 }
#             ],
#             "metric_details": {
#                 "recall": {
#                     "relevant_docs": 7,
#                     "relevant_docs_retrieved": 7
#                 }
#             },
#             "metric_score": 1.0,
#             "unrated_docs": [
#                 {
#                     "_id": "303",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "159",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "139",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "258",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "309",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "115",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "238",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "198",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "318",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "251",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "323",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "90",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "75",
#                     "_index": "time-corpus"
#                 }
#             ]
#         },
#         "Query_13": {
#             "hits": [
#                 {
#                     "hit": {
#                         "_id": "170",
#                         "_index": "time-corpus",
#                         "_score": 25.377111,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "342",
#                         "_index": "time-corpus",
#                         "_score": 22.359257,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "287",
#                         "_index": "time-corpus",
#                         "_score": 22.346443,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "239",
#                         "_index": "time-corpus",
#                         "_score": 18.871964,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "185",
#                         "_index": "time-corpus",
#                         "_score": 16.65105,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "151",
#                         "_index": "time-corpus",
#                         "_score": 16.23736,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "188",
#                         "_index": "time-corpus",
#                         "_score": 16.16289,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "87",
#                         "_index": "time-corpus",
#                         "_score": 15.161155,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "169",
#                         "_index": "time-corpus",
#                         "_score": 15.119489,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "350",
#                         "_index": "time-corpus",
#                         "_score": 14.97838,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "267",
#                         "_index": "time-corpus",
#                         "_score": 14.89386,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "79",
#                         "_index": "time-corpus",
#                         "_score": 13.954836,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "32",
#                         "_index": "time-corpus",
#                         "_score": 12.787891,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "228",
#                         "_index": "time-corpus",
#                         "_score": 12.624637,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "421",
#                         "_index": "time-corpus",
#                         "_score": 12.128833,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "5",
#                         "_index": "time-corpus",
#                         "_score": 12.052214,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "38",
#                         "_index": "time-corpus",
#                         "_score": 11.34021,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "343",
#                         "_index": "time-corpus",
#                         "_score": 11.07505,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "132",
#                         "_index": "time-corpus",
#                         "_score": 10.836697,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "221",
#                         "_index": "time-corpus",
#                         "_score": 10.637828,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 }
#             ],
#             "metric_details": {
#                 "recall": {
#                     "relevant_docs": 3,
#                     "relevant_docs_retrieved": 3
#                 }
#             },
#             "metric_score": 1.0,
#             "unrated_docs": [
#                 {
#                     "_id": "342",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "287",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "239",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "151",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "188",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "169",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "350",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "267",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "79",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "32",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "228",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "421",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "5",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "38",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "343",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "132",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "221",
#                     "_index": "time-corpus"
#                 }
#             ]
#         },
#         "Query_14": {
#             "hits": [
#                 {
#                     "hit": {
#                         "_id": "279",
#                         "_index": "time-corpus",
#                         "_score": 16.355106,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "88",
#                         "_index": "time-corpus",
#                         "_score": 12.679078,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "341",
#                         "_index": "time-corpus",
#                         "_score": 12.262467,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "107",
#                         "_index": "time-corpus",
#                         "_score": 11.971282,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "45",
#                         "_index": "time-corpus",
#                         "_score": 11.31924,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "289",
#                         "_index": "time-corpus",
#                         "_score": 11.150529,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "269",
#                         "_index": "time-corpus",
#                         "_score": 10.969556,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "377",
#                         "_index": "time-corpus",
#                         "_score": 10.868642,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "32",
#                         "_index": "time-corpus",
#                         "_score": 10.763961,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "218",
#                         "_index": "time-corpus",
#                         "_score": 10.397039,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "343",
#                         "_index": "time-corpus",
#                         "_score": 10.385223,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "47",
#                         "_index": "time-corpus",
#                         "_score": 10.1643915,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "239",
#                         "_index": "time-corpus",
#                         "_score": 10.122094,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "382",
#                         "_index": "time-corpus",
#                         "_score": 10.121997,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "310",
#                         "_index": "time-corpus",
#                         "_score": 10.1107435,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "294",
#                         "_index": "time-corpus",
#                         "_score": 10.080088,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "292",
#                         "_index": "time-corpus",
#                         "_score": 10.070625,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "121",
#                         "_index": "time-corpus",
#                         "_score": 10.012019,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "270",
#                         "_index": "time-corpus",
#                         "_score": 10.006958,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "9",
#                         "_index": "time-corpus",
#                         "_score": 9.844368,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 }
#             ],
#             "metric_details": {
#                 "recall": {
#                     "relevant_docs": 1,
#                     "relevant_docs_retrieved": 1
#                 }
#             },
#             "metric_score": 1.0,
#             "unrated_docs": [
#                 {
#                     "_id": "279",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "88",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "341",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "107",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "45",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "289",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "377",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "32",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "218",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "343",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "47",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "239",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "382",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "310",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "294",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "292",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "121",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "270",
# ...
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "315",
#                         "_index": "time-corpus",
#                         "_score": 17.996552,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "275",
#                         "_index": "time-corpus",
#                         "_score": 14.948027,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "350",
#                         "_index": "time-corpus",
#                         "_score": 14.03894,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "8",
#                         "_index": "time-corpus",
#                         "_score": 13.244116,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "411",
#                         "_index": "time-corpus",
#                         "_score": 12.326247,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "27",
#                         "_index": "time-corpus",
#                         "_score": 12.120131,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "221",
#                         "_index": "time-corpus",
#                         "_score": 12.11104,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "156",
#                         "_index": "time-corpus",
#                         "_score": 11.844361,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "77",
#                         "_index": "time-corpus",
#                         "_score": 11.838447,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "290",
#                         "_index": "time-corpus",
#                         "_score": 11.822996,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "291",
#                         "_index": "time-corpus",
#                         "_score": 11.807982,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "329",
#                         "_index": "time-corpus",
#                         "_score": 11.68576,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "418",
#                         "_index": "time-corpus",
#                         "_score": 11.667247,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "280",
#                         "_index": "time-corpus",
#                         "_score": 11.492597,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "49",
#                         "_index": "time-corpus",
#                         "_score": 11.445854,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "272",
#                         "_index": "time-corpus",
#                         "_score": 10.954381,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "405",
#                         "_index": "time-corpus",
#                         "_score": 10.846191,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "41",
#                         "_index": "time-corpus",
#                         "_score": 10.662615,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "306",
#                         "_index": "time-corpus",
#                         "_score": 10.392665,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 }
#             ],
#             "metric_details": {
#                 "recall": {
#                     "relevant_docs": 2,
#                     "relevant_docs_retrieved": 1
#                 }
#             },
#             "metric_score": 0.5,
#             "unrated_docs": [
#                 {
#                     "_id": "315",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "275",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "350",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "8",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "411",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "27",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "221",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "156",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "77",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "290",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "291",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "329",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "418",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "280",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "49",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "272",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "405",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "41",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "306",
#                     "_index": "time-corpus"
#                 }
#             ]
#         },
#         "Query_9": {
#             "hits": [
#                 {
#                     "hit": {
#                         "_id": "358",
#                         "_index": "time-corpus",
#                         "_score": 14.903492,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "339",
#                         "_index": "time-corpus",
#                         "_score": 13.928195,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "269",
#                         "_index": "time-corpus",
#                         "_score": 12.525808,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "156",
#                         "_index": "time-corpus",
#                         "_score": 12.422356,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "61",
#                         "_index": "time-corpus",
#                         "_score": 11.691589,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "242",
#                         "_index": "time-corpus",
#                         "_score": 11.251749,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "155",
#                         "_index": "time-corpus",
#                         "_score": 9.382632,
#                         "_type": "_doc"
#                     },
#                     "rating": 1
#                 },
#                 {
#                     "hit": {
#                         "_id": "422",
#                         "_index": "time-corpus",
#                         "_score": 6.83219,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "303",
#                         "_index": "time-corpus",
#                         "_score": 6.4871755,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "258",
#                         "_index": "time-corpus",
#                         "_score": 6.1391263,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "238",
#                         "_index": "time-corpus",
#                         "_score": 6.0629716,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "198",
#                         "_index": "time-corpus",
#                         "_score": 6.014735,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "179",
#                         "_index": "time-corpus",
#                         "_score": 5.7537513,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "68",
#                         "_index": "time-corpus",
#                         "_score": 4.995761,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "423",
#                         "_index": "time-corpus",
#                         "_score": 4.8730803,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "31",
#                         "_index": "time-corpus",
#                         "_score": 4.6905007,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "46",
#                         "_index": "time-corpus",
#                         "_score": 4.6222076,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "84",
#                         "_index": "time-corpus",
#                         "_score": 4.109038,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "316",
#                         "_index": "time-corpus",
#                         "_score": 4.0255957,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 },
#                 {
#                     "hit": {
#                         "_id": "314",
#                         "_index": "time-corpus",
#                         "_score": 3.992906,
#                         "_type": "_doc"
#                     },
#                     "rating": null
#                 }
#             ],
#             "metric_details": {
#                 "recall": {
#                     "relevant_docs": 8,
#                     "relevant_docs_retrieved": 7
#                 }
#             },
#             "metric_score": 0.875,
#             "unrated_docs": [
#                 {
#                     "_id": "422",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "303",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "258",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "238",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "198",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "179",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "68",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "423",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "31",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "46",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "84",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "316",
#                     "_index": "time-corpus"
#                 },
#                 {
#                     "_id": "314",
#                     "_index": "time-corpus"
#                 }
#             ]
#         }
#     },
#     "failures": {},
#     "metric_score": 0.7715422305075034
# }
